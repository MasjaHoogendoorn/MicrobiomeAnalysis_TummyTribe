# %% [markdown]
# # 4. Phylogeny
#
# Understanding the evolutionary relationships between microbial taxa is a key component of microbiome analysis. Phylogenetic trees provide a framework for interpreting community structure, measuring diversity, and linking taxonomic groups to functional or ecological patterns.
# In this notebook, we generate a de novo phylogenetic tree. This means that all ASVs in our dataset are placed within a consistent evolutionary framework without relying on external reference databases. Building a phylogeny from 16S RNA requires first aligning our sequences and then building the phylogeny that represents the distances between these sequences.
# To assess the reliability of the inferred tree topology, we then perform bootstrapping, a resampling-based approach that quantifies confidence in each clade. Bootstrapping tests how consistently individual branches appear across many pseudo-replicated datasets, allowing us to identify well-supported versus uncertain regions of the tree.
# The final phylogenetic tree can be used for downstream analyses such as UniFrac distance calculation or phylogenetic diversity metrics [[Baldauf. (2003)](https://doi.org/10.1016/S0168-9525(03)00112-4)].
#
#
# ### Notebook Structure
#
# **0.** Setup
# **1.** De novo tree construction
# &nbsp;&nbsp;&nbsp;&nbsp;**1.1** Sequence Alignment
# &nbsp;&nbsp;&nbsp;&nbsp;**1.2** Alignment Masking
# &nbsp;&nbsp;&nbsp;&nbsp;**1.3** Tree Construction
# &nbsp;&nbsp;&nbsp;&nbsp;**1.4** Tree Rooting
# &nbsp;&nbsp;&nbsp;&nbsp;**1.5** Tree Visualization
# &nbsp;&nbsp;&nbsp;&nbsp;**1.6** Bootstrapping
# **2.** Fragment insertion
# &nbsp;&nbsp;&nbsp;&nbsp;**2.1** Silva Reference
# &nbsp;&nbsp;&nbsp;&nbsp;**2.2** Tree Construction using SEPP
# &nbsp;&nbsp;&nbsp;&nbsp;**2.3** Tree Visualization

# %% [markdown]
# ## 0. Setup

# %%
# Import all necessary packages
import os
import pandas as pd
from qiime2 import Visualization
import matplotlib.pyplot as plt
import numpy as np
import qiime2 as q2
from IPython.display import Image, display
# %matplotlib inline

# %% [markdown]
# We are using empress (version 1.2.0) for the tree visualization. Since it is not part of qiime, we need to install the package via pip first.

# %%
# !pip install empress==1.2.0
# Out:
# Collecting empress==1.2.0
#   Using cached empress-1.2.0-py3-none-any.whl
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from empress==1.2.0) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from empress==1.2.0) (1.13.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from empress==1.2.0) (2.2.2)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from empress==1.2.0) (8.1.8)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from empress==1.2.0) (3.1.6)
# Requirement already satisfied: scikit-bio in /opt/conda/lib/python3.10/site-packages (from empress==1.2.0) (0.6.2)
# Requirement already satisfied: biom-format in /opt/conda/lib/python3.10/site-packages (from empress==1.2.0) (2.1.16)
# Requirement already satisfied: iow in /opt/conda/lib/python3.10/site-packages (from empress==1.2.0) (1.0.5)
# Requirement already satisfied: emperor>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from empress==1.2.0) (1.0.4)
# Requirement already satisfied: future in /opt/conda/lib/python3.10/site-packages (from emperor>=1.0.2->empress==1.2.0) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->empress==1.2.0) (3.0.2)
# Requirement already satisfied: requests>=2.20.0 in /opt/conda/lib/python3.10/site-packages (from scikit-bio->empress==1.2.0) (2.32.4)
# Requirement already satisfied: decorator>=3.4.2 in /opt/conda/lib/python3.10/site-packages (from scikit-bio->empress==1.2.0) (4.4.2)
# Requirement already satisfied: natsort>=4.0.3 in /opt/conda/lib/python3.10/site-packages (from scikit-bio->empress==1.2.0) (8.4.0)
# Requirement already satisfied: h5py>=3.6.0 in /opt/conda/lib/python3.10/site-packages (from scikit-bio->empress==1.2.0) (3.11.0)
# Requirement already satisfied: statsmodels>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from scikit-bio->empress==1.2.0) (0.14.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->empress==1.2.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->empress==1.2.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->empress==1.2.0) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->empress==1.2.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20.0->scikit-bio->empress==1.2.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20.0->scikit-bio->empress==1.2.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20.0->scikit-bio->empress==1.2.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20.0->scikit-bio->empress==1.2.0) (2025.7.14)
# Requirement already satisfied: patsy>=0.5.6 in /opt/conda/lib/python3.10/site-packages (from statsmodels>=0.14.0->scikit-bio->empress==1.2.0) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /opt/conda/lib/python3.10/site-packages (from statsmodels>=0.14.0->scikit-bio->empress==1.2.0) (25.0)
# Collecting nose>=1.3.7 (from iow->empress==1.2.0)
#   Using cached nose-1.3.7-py3-none-any.whl.metadata (1.7 kB)
# Collecting cython>=0.24.1 (from iow->empress==1.2.0)
#   Using cached cython-3.2.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting scikit-bio (from empress==1.2.0)
#   Using cached scikit_bio-0.5.9-cp310-cp310-linux_x86_64.whl
# Requirement already satisfied: IPython>=3.2.0 in /opt/conda/lib/python3.10/site-packages (from scikit-bio->empress==1.2.0) (8.21.0)
# Requirement already satisfied: matplotlib>=1.4.3 in /opt/conda/lib/python3.10/site-packages (from scikit-bio->empress==1.2.0) (3.8.4)
# Collecting scipy (from empress==1.2.0)
#   Using cached scipy-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
# Requirement already satisfied: hdmedians>=0.14.1 in /opt/conda/lib/python3.10/site-packages (from scikit-bio->empress==1.2.0) (0.14.2)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from IPython>=3.2.0->scikit-bio->empress==1.2.0) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from IPython>=3.2.0->scikit-bio->empress==1.2.0) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.10/site-packages (from IPython>=3.2.0->scikit-bio->empress==1.2.0) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from IPython>=3.2.0->scikit-bio->empress==1.2.0) (2.19.2)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from IPython>=3.2.0->scikit-bio->empress==1.2.0) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /opt/conda/lib/python3.10/site-packages (from IPython>=3.2.0->scikit-bio->empress==1.2.0) (5.9.0)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from IPython>=3.2.0->scikit-bio->empress==1.2.0) (1.3.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from IPython>=3.2.0->scikit-bio->empress==1.2.0) (4.9.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython>=3.2.0->scikit-bio->empress==1.2.0) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->IPython>=3.2.0->scikit-bio->empress==1.2.0) (0.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.3->scikit-bio->empress==1.2.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.3->scikit-bio->empress==1.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.3->scikit-bio->empress==1.2.0) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.3->scikit-bio->empress==1.2.0) (1.4.8)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.3->scikit-bio->empress==1.2.0) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.3->scikit-bio->empress==1.2.0) (3.2.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->IPython>=3.2.0->scikit-bio->empress==1.2.0) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/conda/lib/python3.10/site-packages (from exceptiongroup->IPython>=3.2.0->scikit-bio->empress==1.2.0) (4.14.1)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->IPython>=3.2.0->scikit-bio->empress==1.2.0) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->IPython>=3.2.0->scikit-bio->empress==1.2.0) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/conda/lib/python3.10/site-packages (from stack-data->IPython>=3.2.0->scikit-bio->empress==1.2.0) (0.2.3)
# Using cached scipy-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
# Using cached cython-3.2.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.5 MB)
# Using cached nose-1.3.7-py3-none-any.whl (154 kB)
# Installing collected packages: nose, scipy, cython, scikit-bio, empress
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.0
#     Uninstalling scipy-1.13.0:
#       Successfully uninstalled scipy-1.13.0━━━━━━━━━━━━━━━━━━━━━━━ 1/5 [scipy]
#   Attempting uninstall: scikit-bio━━━━━━━━━━━━━━━━━━━━━━━ 2/5 [cython]
#     Found existing installation: scikit-bio 0.6.2━━━━━━━━━━━━━ 2/5 [cython]
#     Uninstalling scikit-bio-0.6.2:━━━━━━━━━━━━━━━━━━━━━━━ 2/5 [cython]
#       Successfully uninstalled scikit-bio-0.6.2━━━━━━━━━━━━━━━ 3/5 [scikit-bio]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [empress]m4/5 [empress]io]
# Successfully installed cython-3.2.3 empress-1.2.0 nose-1.3.7 scikit-bio-0.5.9 scipy-1.10.1

# %%
import empress
# Out:
# /opt/conda/lib/python3.10/site-packages/empress/core.py:19: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
# The working directory should normally default to the 'scripts' folder. 
# If it doesn't, set it manually using the command below.
# os.chdir("/home/jovyan/MicrobiomeAnalysis_TummyTribe/scripts")  # Adjust this path to match your folder structure.

# Verify that your working directory is the 'scripts' folder inside the main project directory (.../MicrobiomeAnalysis_TummyTribe/scripts)
cwd = os.getcwd()
if not cwd.endswith("MicrobiomeAnalysis_TummyTribe/scripts"):
    print("WARNING: The working directory is not set to the 'scripts' folder inside 'MicrobiomeAnalysis_TummyTribe'!")
    print("Current working directory:", cwd)
    print("Please set it manually using os.chdir().")
else:
    print(f"Working directory is correctly set to the 'scripts' folder (\"{cwd}\").")
# Out:
# Working directory is correctly set to the 'scripts' folder ("/home/jovyan/Project_final/MicrobiomeAnalysis_TummyTribe/scripts").

# %%
# Data directories
meta_data_dir = "../data/processed/metadata"
raw_data_dir = "../data/raw"
phylogeny_data_dir = "../data/processed/phylogeny"
denoising_data_dir = "../data/processed/denoising"
taxonomy_data_dir = "../data/processed/taxonomy"

# %%
# %%bash -s "$phylogeny_data_dir"
# mkdir -p "$1"

# %% [markdown]
# ## 1. De novo tree construction
# We can create a phylogenetic tree by aligning the marker genes across divergent taxa and try to reconstruct the tree based on the resulting alignment. One of the issues of this approach is that short sequences may not carry enough information to capture a meaningful phylogeny. Generally fragment insertion is recommended for 16S rRNA data, but since our goal is to study evolutionary patterns and diversity within our cohort, it makes sense to use de novo tree construction [[Price et al. (2010)](https://doi.org/10.1371/journal.pone.0009490)]. Fragment insertion is described as an alternative method further down in this notebook but will not be used in our analysis.
#
# Standard pipeline for de novo tree construction:
# 1. MAFFT multiple-sequence alignment
# 2. Masking (filtering) the alignment
# 3. FastTree (or RAxML/IQ-TREE) tree inference
# 4. Midpoint rooting
#
# After MAFFT aligns the ASVs, QIIME masks the alignment to remove hypervariable, gappy, or uninformative positions that would distort phylogenetic inference. The masked alignment is then passed to FastTree, which uses an approximate maximum-likelihood algorithm (GTR+CAT model) to rapidly construct a de novo phylogeny optimized for large microbial datasets.

# %% [markdown]
# ### 1.1 Sequence alignemnt

# %%
! qiime alignment mafft \
    --i-sequences $taxonomy_data_dir/dada2_rep_seq_filtered.qza \
    --o-alignment $phylogeny_data_dir/aligned-rep-seqs.qza
# Out:
# QIIME is caching your current deployment for improved performance. This may take a few moments and should only happen once per deployment.
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Saved FeatureData[AlignedSequence] to: ../data/processed/phylogeny/aligned-rep-seqs.qza

# %% [markdown]
# ### 1.2 Alignment masking

# %%
! qiime alignment mask \
    --i-alignment $phylogeny_data_dir/aligned-rep-seqs.qza \
    --o-masked-alignment $phylogeny_data_dir/masked-aligned-rep-seqs.qza
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Saved FeatureData[AlignedSequence] to: ../data/processed/phylogeny/masked-aligned-rep-seqs.qza

# %% [markdown]
# ### 1.3 Tree inference

# %%
! qiime phylogeny fasttree \
    --i-alignment $phylogeny_data_dir/masked-aligned-rep-seqs.qza \
    --o-tree $phylogeny_data_dir/fasttree-tree.qza

! qiime phylogeny midpoint-root \
    --i-tree $phylogeny_data_dir/fasttree-tree.qza \
    --o-rooted-tree $phylogeny_data_dir/fasttree-tree-rooted.qza
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Saved Phylogeny[Unrooted] to: ../data/processed/phylogeny/fasttree-tree.qza
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Saved Phylogeny[Rooted] to: ../data/processed/phylogeny/fasttree-tree-rooted.qza

# %% [markdown]
# ### 1.4 Tree rooting

# %%
! qiime empress tree-plot \
    --i-tree $phylogeny_data_dir/fasttree-tree-rooted.qza \
    --m-feature-metadata-file $taxonomy_data_dir/taxonomy.qza \
    --o-visualization $phylogeny_data_dir/fasttree-tree-rooted.qzv
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Saved Visualization to: ../data/processed/phylogeny/fasttree-tree-rooted.qzv

# %% [markdown]
# ### 1.5 Tree viszualization

# %%
! qiime empress community-plot \
    --i-tree $phylogeny_data_dir/fasttree-tree-rooted.qza \
    --i-feature-table $taxonomy_data_dir/dada2_table_filtered.qza \
    --m-sample-metadata-file $meta_data_dir/metadata_merged.tsv \
    --m-feature-metadata-file $taxonomy_data_dir/taxonomy.qza \
    --p-filter-extra-samples \
    --o-visualization $phylogeny_data_dir/fasttree-community-tree-viz.qzv
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Saved Visualization to: ../data/processed/phylogeny/fasttree-community-tree-viz.qzv

# %%
Visualization.load(f"{phylogeny_data_dir}/fasttree-community-tree-viz.qzv")
# Out:
# <visualization: Visualization uuid: ab8ba397-1386-47c3-b576-be5c79557186>

# %% [markdown]
# In the interactive tree visualization we suggest to change the layout to rectangular or circular to see the relationships better. Additionally you can color by Feature Metadata at level 6 (genus level). You can also try to color by Sample Metadata.

# %% [markdown]
# ### 1.5 Bootstrapping
# Bootstrapping provides confidence values for each branch and helps identify which parts of the tree are well supported versus uncertain. This is done by taking random subsamples of the dataset, building trees from each of these and calculating the frequency with which the various parts of our de novo tree are reproduced in each of these random subsamples [[Baldauf. (2003)](https://doi.org/10.1016/S0168-9525(03)00112-4)].
#
# It is important to mention that bootstrapping can't help with any of the shortcomings of a de novo tree. Bootstrapping measures confidence, but does not improve accuracy. A weak or biased de novo tree remains weak or biased, even with high bootstrap support.
#
# This cell does run in the notebook, but you might want to get a coffee (or two) since it takes about 4 hours. We did run this on euler, but there is no script in the "additional" because the cell would run in the notebook. We did however include a cell to download the bootstrap tree from Laura's Polybox. So you can either run the bootstrapping yourself or download the finished tree.

# %%
! qiime phylogeny raxml-rapid-bootstrap \
    --i-alignment $phylogeny_data_dir/masked-aligned-rep-seqs.qza \
    --p-seed 1723 \
    --p-rapid-bootstrap-seed 9384 \
    --p-bootstrap-replicates 100 \
    --p-substitution-model GTRCAT \
    --p-n-threads 3 \
    --o-tree $phylogeny_data_dir/raxml-cat-bootstrap-tree.qza
# Out:
#   Cell In[4], line 2
#     --verbose
#     ^
# IndentationError: unexpected indent

# %%
# %%bash -s "$phylogeny_data_dir"
# mkdir -p "$1"
#
# # import boostrap tree from Laura's Polybox into phylogeny folder
# wget --progress=bar:force:noscroll \
#   -O "$1/bootstrapped_tree.png" \
#   "https://polybox.ethz.ch/index.php/s/s7NrFfY7sCJNzFy/download"
# Out:
# --2025-12-17 07:39:13--  https://polybox.ethz.ch/index.php/s/s7NrFfY7sCJNzFy/download
# Resolving polybox.ethz.ch (polybox.ethz.ch)... 129.132.71.243
# Connecting to polybox.ethz.ch (polybox.ethz.ch)|129.132.71.243|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 425904 (416K) [image/png]
# Saving to: ‘../data/processed/phylogeny/bootstrapped_tree.png’
#
# ../data/processed/p 100%[===================>] 415.92K  --.-KB/s    in 0.002s
#
# 2025-12-17 07:39:14 (163 MB/s) - ‘../data/processed/phylogeny/bootstrapped_tree.png’ saved [425904/425904]

# %%
! qiime phylogeny midpoint-root \
    --i-tree $phylogeny_data_dir/raxml-cat-bootstrap-tree.qza \
    --o-rooted-tree $phylogeny_data_dir/raxml-cat-bootstrap-tree-rooted.qza
# Out:
# QIIME is caching your current deployment for improved performance. This may take a few moments and should only happen once per deployment.
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Saved Phylogeny[Rooted] to: ../data/processed/phylogeny/raxml-cat-bootstrap-tree-rooted.qza

# %% [markdown]
# To see the confidence values added to the branches, we need to export the bootstrapped tree as a NWK file. This tree can then be viewed in [iTOL](https://itol.embl.de/upload.cgi). The tree with the coloured confidence values can be downloaded from polybox and displayed.

# %%
! qiime tools export \
      --input-path $phylogeny_data_dir/raxml-cat-bootstrap-tree.qza \
      --output-path $phylogeny_data_dir/raxml_bootstrap_tree
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Exported ../data/processed/phylogeny/raxml-cat-bootstrap-tree.qza as NewickDirectoryFormat to directory ../data/processed/phylogeny/raxml_bootstrap_tree

# %%
# %%bash -s "$phylogeny_data_dir"
# mkdir -p "$1"
#
# # import boostrap tree from Laura's Polybox into phylogeny folder
# wget --progress=bar:force:noscroll \
#   -O "$1/bootstrapped_tree.png" \
#   "https://polybox.ethz.ch/index.php/s/s7NrFfY7sCJNzFy/download"
# Out:
# --2025-12-17 07:39:13--  https://polybox.ethz.ch/index.php/s/s7NrFfY7sCJNzFy/download
# Resolving polybox.ethz.ch (polybox.ethz.ch)... 129.132.71.243
# Connecting to polybox.ethz.ch (polybox.ethz.ch)|129.132.71.243|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 425904 (416K) [image/png]
# Saving to: ‘../data/processed/phylogeny/bootstrapped_tree.png’
#
# ../data/processed/p 100%[===================>] 415.92K  --.-KB/s    in 0.002s
#
# 2025-12-17 07:39:14 (163 MB/s) - ‘../data/processed/phylogeny/bootstrapped_tree.png’ saved [425904/425904]

# %%
path = path = os.path.join(phylogeny_data_dir, "bootstrapped_tree.png")
display(Image(filename=path, width=800))

# %% [markdown]
# We can see that the branches closer to the root have lower confidence values, while the branches closer to the tips have higher confidence values.

# %% [markdown]
# ## 2. Fragment insertion

# %% [markdown]
# Fragment insertion uses a reference tree and then our sequences are inserted into this tree. This results in a way larger tree than if we construct a de novo tree since it includes the entire reference backbone tree. We can get the SILVA 128 reference tree from qiime. According to a user in the qiime forum using SILVA 138 for the taxonomy and SILVA 128 to build the phylogenetic tree should not lead to any complications [[Qiime2 Forum](https://forum.qiime2.org/t/compatibility-of-sepp-silva128-with-taxonomy-classification-using-silva138/31172?utm_source=chatgpt.com)].
#
# For our analysis we have decided to use the de novo tree since it is easier to construct and works well with the dataset that we are using.

# %% [markdown]
# ### 2.1 Silva Reference

# %%
#SILVA 128 for SEPP
! wget -O $phylogeny_data_dir/silva-128-sepp-refs.qza https://data.qiime2.org/classifiers/sepp-ref-dbs/sepp-refs-silva-128.qza
# Out:
# --2025-12-10 14:41:52--  https://data.qiime2.org/classifiers/sepp-ref-dbs/sepp-refs-silva-128.qza
# Resolving data.qiime2.org (data.qiime2.org)... 54.200.1.12
# Connecting to data.qiime2.org (data.qiime2.org)|54.200.1.12|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://s3-us-west-2.amazonaws.com/qiime2-data/classifiers/sepp-ref-dbs/sepp-refs-silva-128.qza [following]
# --2025-12-10 14:41:52--  https://s3-us-west-2.amazonaws.com/qiime2-data/classifiers/sepp-ref-dbs/sepp-refs-silva-128.qza
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.253.64, 52.92.206.224, 52.218.183.104, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.253.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 181253322 (173M) [binary/octet-stream]
# Saving to: ‘../data/processed/phylogeny/silva-128-sepp-refs.qza’
#
# ../data/processed/p 100%[===================>] 172.86M  16.7MB/s    in 12s
#
# 2025-12-10 14:42:05 (14.6 MB/s) - ‘../data/processed/phylogeny/silva-128-sepp-refs.qza’ saved [181253322/181253322]

# %% [markdown]
# ### 2.2 Tree construction using SEPP
# The following cell does not run in this notebook due to limited memory. It was run on euler and the finished tree and tree placements can be imported from Laura's Polybox for visualization. The euler script can be found in the additional script folder (4_euler_script_build_SEPP_tree).

# %%
#does not run in notebook -> euler (needs amplicon env)
"""
! qiime fragment-insertion sepp \
    --i-representative-sequences $taxonomy_data_dir/dada2_rep_seq_filtered.qza \
    --i-reference-database $phylogeny_data_dir/silva-128-sepp-refs.qza \
    --p-threads 2 \
    --o-tree $phylogeny_data_dir/sepp-tree.qza \
    --o-placements $phylogeny_data_dir/sepp-tree-placements.qza \
    --verbose
"""
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Removing /tmp/tmp.1ZZbpa3ZS5/sepp-tmp-QfUBleakIt

# %%
# %%bash -s "$phylogeny_data_dir"
# mkdir -p "$1"
#
# # import tree placements from Laura's Polybox into phylogeny folder
# wget --progress=bar:force:noscroll \
#   -O "$1/sepp-tree.qza" \
#   "https://polybox.ethz.ch/index.php/s/bjpHof33mcjpJC2/download"
#
# wget --progress=bar:force:noscroll \
#   -O "$1/sepp-tree-placements.qza" \
#   "https://polybox.ethz.ch/index.php/s/QrzAqRXbQNFPFzK/download"
# Out:
# --2025-12-11 09:31:35--  https://polybox.ethz.ch/index.php/s/bjpHof33mcjpJC2/download
# Resolving polybox.ethz.ch (polybox.ethz.ch)... 129.132.71.243
# Connecting to polybox.ethz.ch (polybox.ethz.ch)|129.132.71.243|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6183927 (5.9M) [application/octet-stream]
# Saving to: ‘../data/processed/phylogeny/sepp-tree.qza’
#
# ../data/processed/p 100%[===================>]   5.90M  --.-KB/s    in 0.02s
#
# 2025-12-11 09:31:35 (259 MB/s) - ‘../data/processed/phylogeny/sepp-tree.qza’ saved [6183927/6183927]
#
# --2025-12-11 09:31:35--  https://polybox.ethz.ch/index.php/s/QrzAqRXbQNFPFzK/download
# Resolving polybox.ethz.ch (polybox.ethz.ch)... 129.132.71.243
# Connecting to polybox.ethz.ch (polybox.ethz.ch)|129.132.71.243|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12699735 (12M) [application/octet-stream]
# Saving to: ‘../data/processed/phylogeny/sepp-tree-placements.qza’
#
# ../data/processed/p 100%[===================>]  12.11M  --.-KB/s    in 0.07s
#
# 2025-12-11 09:31:35 (168 MB/s) - ‘../data/processed/phylogeny/sepp-tree-placements.qza’ saved [12699735/12699735]

# %% [markdown]
# ### 2.3 Tree visualization

# %%
! qiime empress tree-plot \
    --i-tree $phylogeny_data_dir/sepp-tree.qza \
    --m-feature-metadata-file $taxonomy_data_dir/taxonomy.qza \
    --o-visualization $phylogeny_data_dir/sepp-tree.qzv
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Saved Visualization to: ../data/processed/phylogeny/sepp-tree.qzv

# %%
! qiime empress community-plot \
    --i-tree $phylogeny_data_dir/sepp-tree.qza \
    --i-feature-table $taxonomy_data_dir/dada2_table_filtered.qza \
    --m-sample-metadata-file $meta_data_dir/metadata_merged.tsv \
    --m-feature-metadata-file $taxonomy_data_dir/taxonomy.qza \
    --p-filter-extra-samples \
    --o-visualization $phylogeny_data_dir/sepp-community-tree-viz-filtered.qzv
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Saved Visualization to: ../data/processed/phylogeny/sepp-community-tree-viz-filtered.qzv

# %%
Visualization.load(f"{phylogeny_data_dir}/sepp-community-tree-viz-filtered.qzv")
# Out:
# <visualization: Visualization uuid: 15d4abfd-77b8-42ee-8694-d184243d3b7e>

# %% [markdown]
# We suggest to choose a linear layout for this tree and to colour by Feature Metadata Level 6 in the interactive visualization. We can see that this tree contains way more information, which comes from the SILVA backbone. For the reasons mentioned earlier in this notebook, we decided together with our TA to not use this tree but the de novo tree that we built before.

# %% [markdown]
# ## References
#
# Baldauf SL. Phylogeny for the faint of heart: a tutorial. Trends Genet. (2003). https://doi.org/10.1016/S0168-9525(03)00112-4
#
# Price MN, Dehal PS, Arkin AP. FastTree 2--approximately maximum-likelihood trees for large alignments. PLoS One. (2010). https://doi.org/10.1371/journal.pone.0009490
